# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
df=pd.read_csv('/kaggle/input/loan-approval-dataset-csv/loan_approval_dataset.csv')

# %%
print(df)
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0           1                  2       Graduate             No        9600000
# 1           2                  0   Not Graduate            Yes        4100000
# 2           3                  3       Graduate             No        9100000
# 3           4                  3       Graduate             No        8200000
# 4           5                  5   Not Graduate            Yes        9800000
# ...       ...                ...            ...            ...            ...
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
# ...

# %%
df.columns = df.columns.str.strip()

# %%
print(df.columns)
# Out:
# Index(['loan_id', 'no_of_dependents', 'education', 'self_employed',
#        'income_annum', 'loan_amount', 'loan_term', 'cibil_score',
#        'residential_assets_value', 'commercial_assets_value',
#        'luxury_assets_value', 'bank_asset_value', 'loan_status'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['loan_id', 'no_of_dependents', 'education', 'self_employed',
#        'income_annum', 'loan_amount', 'loan_term', 'cibil_score',
#        'residential_assets_value', 'commercial_assets_value',
#        'luxury_assets_value', 'bank_asset_value', 'loan_status'],
#       dtype='object')

# %%
df['Assets']=df.residential_assets_value+df.commercial_assets_value+df.luxury_assets_value+df.bank_asset_value

# %%
df.columns
# Out:
# Index(['loan_id', 'no_of_dependents', 'education', 'self_employed',
#        'income_annum', 'loan_amount', 'loan_term', 'cibil_score',
#        'residential_assets_value', 'commercial_assets_value',
#        'luxury_assets_value', 'bank_asset_value', 'loan_status', 'Assets'],
#       dtype='object')

# %%
print(df)
# Out:
#       loan_id  no_of_dependents      education self_employed  income_annum  \
# 0           1                 2       Graduate            No       9600000
# 1           2                 0   Not Graduate           Yes       4100000
# 2           3                 3       Graduate            No       9100000
# 3           4                 3       Graduate            No       8200000
# 4           5                 5   Not Graduate           Yes       9800000
# ...       ...               ...            ...           ...           ...
# 4264     4265                 5       Graduate           Yes       1000000
# 4265     4266                 0   Not Graduate           Yes       3300000
# 4266     4267                 2   Not Graduate            No       6500000
# 4267     4268                 1   Not Graduate            No       4100000
# 4268     4269                 1       Graduate            No       9200000
#
# ...

# %%
df.columns = df.columns.str.strip()  # Removes any leading or trailing spaces
df.drop(columns=['residential_assets_value', 'commercial_assets_value', 'luxury_assets_value', 'bank_asset_value'], inplace=True)

# %%
print(df)
# Out:
#       loan_id  no_of_dependents      education self_employed  income_annum  \
# 0           1                 2       Graduate            No       9600000
# 1           2                 0   Not Graduate           Yes       4100000
# 2           3                 3       Graduate            No       9100000
# 3           4                 3       Graduate            No       8200000
# 4           5                 5   Not Graduate           Yes       9800000
# ...       ...               ...            ...           ...           ...
# 4264     4265                 5       Graduate           Yes       1000000
# 4265     4266                 0   Not Graduate           Yes       3300000
# 4266     4267                 2   Not Graduate            No       6500000
# 4267     4268                 1   Not Graduate            No       4100000
# 4268     4269                 1       Graduate            No       9200000
#
#       loan_amount  loan_term  cibil_score loan_status    Assets
# ...

# %%
df.isnull().sum()
# Out:
# loan_id             0
# no_of_dependents    0
# education           0
# self_employed       0
# income_annum        0
# loan_amount         0
# loan_term           0
# cibil_score         0
# loan_status         0
# Assets              0
# dtype: int64

# %%
df
# Out:
#       loan_id  no_of_dependents      education self_employed  income_annum  \
# 0           1                 2       Graduate            No       9600000
# 1           2                 0   Not Graduate           Yes       4100000
# 2           3                 3       Graduate            No       9100000
# 3           4                 3       Graduate            No       8200000
# 4           5                 5   Not Graduate           Yes       9800000
# ...       ...               ...            ...           ...           ...
# 4264     4265                 5       Graduate           Yes       1000000
# 4265     4266                 0   Not Graduate           Yes       3300000
# 4266     4267                 2   Not Graduate            No       6500000
# 4267     4268                 1   Not Graduate            No       4100000
# 4268     4269                 1       Graduate            No       9200000
#
#       loan_amount  loan_term  cibil_score loan_status    Assets
# ...

# %%
df.education.unique()
# Out:
# array([' Graduate', ' Not Graduate'], dtype=object)

# %%
def Cln_df(st):
    st=st.strip()
    return st

# %%
df.education=df.education.apply(Cln_df)

# %%
df.education.unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %%
df['education']=df['education'].replace(['Graduate','Not Graduate'],[1,0])
# Out:
# <ipython-input-116-040ce4a09a7c>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['education']=df['education'].replace(['Graduate','Not Graduate'],[1,0])

# %%
df
# Out:
#       loan_id  no_of_dependents  education self_employed  income_annum  \
# 0           1                 2          1            No       9600000
# 1           2                 0          0           Yes       4100000
# 2           3                 3          1            No       9100000
# 3           4                 3          1            No       8200000
# 4           5                 5          0           Yes       9800000
# ...       ...               ...        ...           ...           ...
# 4264     4265                 5          1           Yes       1000000
# 4265     4266                 0          0           Yes       3300000
# 4266     4267                 2          0            No       6500000
# 4267     4268                 1          0            No       4100000
# 4268     4269                 1          1            No       9200000
#
#       loan_amount  loan_term  cibil_score loan_status    Assets
# ...

# %%
df.self_employed=df.self_employed.apply(Cln_df)
df.loan_status=df.loan_status.apply(Cln_df)

# %% [markdown]
# **DATA CLEAN KARNA MT BHULO SIR**

# %%
df['self_employed']=df['self_employed'].replace(['Yes','No'],[1,0])
df['loan_status']=df['loan_status'].replace(['Approved','Rejected'],[1,0])
df
# Out:
# <ipython-input-119-a185666a7150>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['self_employed']=df['self_employed'].replace(['Yes','No'],[1,0])
# <ipython-input-119-a185666a7150>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['loan_status']=df['loan_status'].replace(['Approved','Rejected'],[1,0])
#       loan_id  no_of_dependents  education  self_employed  income_annum  \
# 0           1                 2          1              0       9600000
# ...

# %%
df
# Out:
#       loan_id  no_of_dependents  education  self_employed  income_annum  \
# 0           1                 2          1              0       9600000
# 1           2                 0          0              1       4100000
# 2           3                 3          1              0       9100000
# 3           4                 3          1              0       8200000
# 4           5                 5          0              1       9800000
# ...       ...               ...        ...            ...           ...
# 4264     4265                 5          1              1       1000000
# 4265     4266                 0          0              1       3300000
# 4266     4267                 2          0              0       6500000
# 4267     4268                 1          0              0       4100000
# 4268     4269                 1          1              0       9200000
#
#       loan_amount  loan_term  cibil_score  loan_status    Assets
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
input_df=df.drop(columns=['loan_status'])
output_df=df['loan_status']
df
# Out:
#       loan_id  no_of_dependents  education  self_employed  income_annum  \
# 0           1                 2          1              0       9600000
# 1           2                 0          0              1       4100000
# 2           3                 3          1              0       9100000
# 3           4                 3          1              0       8200000
# 4           5                 5          0              1       9800000
# ...       ...               ...        ...            ...           ...
# 4264     4265                 5          1              1       1000000
# 4265     4266                 0          0              1       3300000
# 4266     4267                 2          0              0       6500000
# 4267     4268                 1          0              0       4100000
# 4268     4269                 1          1              0       9200000
#
#       loan_amount  loan_term  cibil_score  loan_status    Assets
# ...

# %%
input_df
# Out:
#       loan_id  no_of_dependents  education  self_employed  income_annum  \
# 0           1                 2          1              0       9600000
# 1           2                 0          0              1       4100000
# 2           3                 3          1              0       9100000
# 3           4                 3          1              0       8200000
# 4           5                 5          0              1       9800000
# ...       ...               ...        ...            ...           ...
# 4264     4265                 5          1              1       1000000
# 4265     4266                 0          0              1       3300000
# 4266     4267                 2          0              0       6500000
# 4267     4268                 1          0              0       4100000
# 4268     4269                 1          1              0       9200000
#
#       loan_amount  loan_term  cibil_score    Assets
# ...

# %%
output_df
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4264    0
# 4265    1
# 4266    0
# 4267    1
# 4268    1
# Name: loan_status, Length: 4269, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(input_df,output_df,test_size=0.2)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((3415, 9), (854, 9), (3415,), (854,))

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled= scaler.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
model= LogisticRegression()

# %%
model.fit(x_train_scaled,y_train)
# Out:
# LogisticRegression()

# %%
model.score(x_test_scaled,y_test)
# Out:
# 0.9156908665105387

# %%
df
# Out:
#       loan_id  no_of_dependents  education  self_employed  income_annum  \
# 0           1                 2          1              0       9600000
# 1           2                 0          0              1       4100000
# 2           3                 3          1              0       9100000
# 3           4                 3          1              0       8200000
# 4           5                 5          0              1       9800000
# ...       ...               ...        ...            ...           ...
# 4264     4265                 5          1              1       1000000
# 4265     4266                 0          0              1       3300000
# 4266     4267                 2          0              0       6500000
# 4267     4268                 1          0              0       4100000
# 4268     4269                 1          1              0       9200000
#
#       loan_amount  loan_term  cibil_score  loan_status    Assets
# ...

# %%
import pickle as pk
pk.dump(model,open('model.pk1','wb'))
pk.dump(scaler,open('scaler.pk1','wb'))
